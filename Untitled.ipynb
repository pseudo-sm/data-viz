# %%
import pandas as pd

# %%
covid_data = pd.read_csv("sales_data_sample.csv",encoding = "ISO-8859-1")

# %%
covid_data.head()
# Out:
#    Unnamed: 0  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# 0          10        10223               37     100.00                1
# 1          21        10361               20      72.55               13
# 2          40        10270               21     100.00                9
# 3          47        10347               30     100.00                1
# 4          51        10391               24     100.00                4
#
#      SALES        ORDERDATE   STATUS  QTR_ID  MONTH_ID  ...  \
# 0  3965.66   2/20/2004 0:00  Shipped       1         2  ...
# 1  1451.00  12/17/2004 0:00  Shipped       4        12  ...
# 2  4905.39   7/19/2004 0:00  Shipped       3         7  ...
# 3  3944.70  11/29/2004 0:00  Shipped       4        11  ...
# 4  2416.56    3/9/2005 0:00  Shipped       1         3  ...
#
#                               ADDRESSLINE1 ADDRESSLINE2          CITY  \
# 0                        636 St Kilda Road      Level 3     Melbourne
# ...

# %%
covid_data.head()
# Out:
#    Unnamed: 0  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# 0          10        10223               37     100.00                1
# 1          21        10361               20      72.55               13
# 2          40        10270               21     100.00                9
# 3          47        10347               30     100.00                1
# 4          51        10391               24     100.00                4
#
#      SALES        ORDERDATE   STATUS  QTR_ID  MONTH_ID  ...  \
# 0  3965.66   2/20/2004 0:00  Shipped       1         2  ...
# 1  1451.00  12/17/2004 0:00  Shipped       4        12  ...
# 2  4905.39   7/19/2004 0:00  Shipped       3         7  ...
# 3  3944.70  11/29/2004 0:00  Shipped       4        11  ...
# 4  2416.56    3/9/2005 0:00  Shipped       1         3  ...
#
#                               ADDRESSLINE1 ADDRESSLINE2          CITY  \
# 0                        636 St Kilda Road      Level 3     Melbourne
# ...

# %%
covid_data["STATUS"].unique()
# Out:
# array(['Shipped', 'In Process'], dtype=object)

# %%
import numpy as np

# %%
chart_data = pd.DataFrame(
     np.random.randn(20, 3),
     columns=['a', 'b', 'c'])

# %%
temp = pd.DataFrame(covid_data.groupby(["STATE"]).sum("SALES")["SALES"])

# %%
chart_data.head()
# Out:
#           a         b         c
# 0  0.096788  1.790608  1.373889
# 1 -0.528797 -0.935405  1.103635
# 2  0.382431 -0.110581  0.855479
# 3 -1.405108 -0.338718 -0.018463
# 4  0.790858 -1.351652  1.416778

# %%
temp.columns.name=None

# %%
temp.head()
# Out:
#               SALES
# STATE
# NSW       305567.11
# Victoria  200995.41

# %%
covid_data[covid_data["STATE"].isin(["NSW"])]
# Out:
#      Unnamed: 0  ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# 1            21        10361               20      72.55               13
# 2            40        10270               21     100.00                9
# 4            51        10391               24     100.00                4
# 7            75        10361               26      51.15                8
# 10          147        10270               32     100.00                2
# ..          ...          ...              ...        ...              ...
# 138        2628        10270               46      88.00                4
# 141        2660        10361               44      72.42                5
# 144        2685        10361               44     100.00               10
# 145        2764        10361               35     100.00               11
# 146        2791        10361               23      95.20               12
#
#        SALES        ORDERDATE   STATUS  QTR_ID  MONTH_ID  ...  \
# ...
